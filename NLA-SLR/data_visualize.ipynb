# %%
import pickle

data_train_path = '../../data/wlasl_2000/train.pkl'
data_dev_path = '../../data/wlasl_2000/dev.pkl'
data_test_path = '../../data/wlasl_2000/test.pkl'

# %%
with open(data_train_path, 'rb') as f:
    data_train = pickle.load(f)

# %%
data_train[1]
# Out:
# {'video_file': 'WLASL2000/65225.mp4',
#  'name': '65225',
#  'seq_len': 64,
#  'label': 'book'}

# %%
labels = []
for i in data_train:
    if i['label'] not in labels:
        labels.append(i['label'])

# %%
for label in labels:
    print(label)

# %%
with open(data_test_path, 'rb') as f:
    data_test = pickle.load(f)

# %%
with open(data_dev_path, 'rb') as f:
    data_dev = pickle.load(f)

# %%
print(len(data_train))
print(len(data_test))
print(len(data_dev))
# Out:
# 14689
# 2878
# 4316

# %%
import os

# %%
print(type(data_train))
k=0
data_train_new = []
data_test_new = []
data_dev_new = []

print(len(data_train))
for i in data_train:
    #print(i)
    path ='/data/wlasl_2000/'+i['video_file']
    #print(path)
    if os.path.exists(path):
        #print(i)
        data_train_new.append(i)
        k+=1
print(k)

k=0
print(len(data_dev))
for i in data_dev:
    #print(i)
    path ='/data/wlasl_2000/'+i['video_file']
    #print(path)
    if os.path.exists(path):
        #print(i)
        data_dev_new.append(i)
        k+=1
print(k)


k=0
print(len(data_test))
for i in data_test:
    #print(i)
    path ='/data/wlasl_2000/'+i['video_file']
    #print(path)
    if os.path.exists(path):
        #print(i)
        data_test_new.append(i)
        k+=1
print(k)
# Out:
# <class 'list'>
# 14689
# 8943
# 4316
# 2222
# 2878
# 1617

# %%
with open( '../../data/wlasl_2000/train_new.pkl', 'wb') as f:
    pickle.dump(data_train_new, f)

# %%
with open( '../../data/wlasl_2000/test_new.pkl', 'wb') as f:
    pickle.dump(data_test_new, f)

with open( '../../data/wlasl_2000/dev_new.pkl', 'wb') as f:
    pickle.dump(data_dev_new, f)

# %%
import pickle

data_train_path = '../../data/wlasl_2000/train_new.pkl'
data_dev_path = '../../data/wlasl_2000/dev_new.pkl'
data_test_path = '../../data/wlasl_2000/test_new.pkl'

with open(data_train_path, 'rb') as f:
    data_train_new = pickle.load(f)
with open(data_test_path, 'rb') as f:
    data_test_new = pickle.load(f)
with open(data_dev_path, 'rb') as f:
    data_dev_new = pickle.load(f)

# %%
import cv2

# %%
labels = {}

for i in data_dev_new:
    if i['label'] not in labels:
        labels[i['label']]=1
    else:
        labels[i['label']]+=1
from matplotlib import pyplot as plt
names = list(labels.keys())
values = list(labels.values())
print(len(names))
#plt.bar(range(len(labels)), values, tick_label=None)
plt.plot(range(len(labels)), values)#, tick_label=None)

plt.show()
# Out:
# 1656
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[36], line 12
#      10 values = list(labels.values())
#      11 print(len(names))
# ---> 12 plt.plot(range(len(labels)), values, tick_label=None)
#      13 plt.show()
#
# File ~/.conda/envs/nla-slr-39/lib/python3.9/site-packages/matplotlib/pyplot.py:2812, in plot(scalex, scaley, data, *args, **kwargs)
#    2810 @_copy_docstring_and_deprecators(Axes.plot)
#    2811 def plot(*args, scalex=True, scaley=True, data=None, **kwargs):
# -> 2812     return gca().plot(
#    2813         *args, scalex=scalex, scaley=scaley,
#    2814         **({"data": data} if data is not None else {}), **kwargs)
#
# File ~/.conda/envs/nla-slr-39/lib/python3.9/site-packages/matplotlib/axes/_axes.py:1688, in Axes.plot(self, scalex, scaley, data, *args, **kwargs)
#    1445 """
#    1446 Plot y versus x as lines and/or markers.
#    1447
# ...

# %%
# Out:
# 1999

# %%
frame_width_list = []
frame_height_list = []

for file in data_train_new:
    path ='/data/wlasl_2000/'+file['video_file']
    #print(path)
    #cap = cv2.VideoCapture(os.path.join(path, file))
    cap = cv2.VideoCapture(path)
    frame_width, frame_height = int(cap.get(3)), int(cap.get(4))
    frame_width_list.append(frame_width)
    frame_height_list.append(frame_height)

for file in data_test_new:
    path ='/data/wlasl_2000/'+file['video_file']
    #print(path)
    #cap = cv2.VideoCapture(os.path.join(path, file))
    cap = cv2.VideoCapture(path)
    frame_width, frame_height = int(cap.get(3)), int(cap.get(4))
    frame_width_list.append(frame_width)
    frame_height_list.append(frame_height)
for file in data_dev_new:
    path ='/data/wlasl_2000/'+file['video_file']
    #print(path)
    #cap = cv2.VideoCapture(os.path.join(path, file))
    cap = cv2.VideoCapture(path)
    frame_width, frame_height = int(cap.get(3)), int(cap.get(4))
    frame_width_list.append(frame_width)
    frame_height_list.append(frame_height)

# %%
from matplotlib import pyplot as plt
plt.hist(frame_width_list, 100)

plt.show()

# %%
plt.hist(frame_height_list, 100)

plt.show()

# %%
for file in data_train_new:
    path ='/data/wlasl_2000/'+file['video_file']   
    cap = cv2.VideoCapture(path)
    resize =256
    dest_path = '/data/wlasl_2000/wlasl_resized/'+file['video_file']

    frame_width, frame_height = int(cap.get(3)), int(cap.get(4))


    out = cv2.VideoWriter(dest_path, cv2.VideoWriter_fourcc(
        'm', 'p', '4', 'v'), 30, (resize, resize))



    while cap.isOpened():
        success, image = cap.read()
        if not success:
            print("Ignoring empty camera frame.")
            # If loading a video, use 'break' instead of 'continue'.
            break
        #ret, frame = cap.read()
        img = cv2.resize(image, (resize, resize))

        out.write(img)
    cap.release()
    out.release()
# Out:
# Ignoring empty camera frame.
# Ignoring empty camera frame.
# Ignoring empty camera frame.
# Ignoring empty camera frame.
# Ignoring empty camera frame.
# Ignoring empty camera frame.
# Ignoring empty camera frame.
# Ignoring empty camera frame.
# Ignoring empty camera frame.
# Ignoring empty camera frame.
# Ignoring empty camera frame.
# Ignoring empty camera frame.
# Ignoring empty camera frame.
# Ignoring empty camera frame.
# Ignoring empty camera frame.
# Ignoring empty camera frame.
# Ignoring empty camera frame.
# Ignoring empty camera frame.
# Ignoring empty camera frame.
# Ignoring empty camera frame.
# Ignoring empty camera frame.
# Ignoring empty camera frame.
# Ignoring empty camera frame.
# Ignoring empty camera frame.
# Ignoring empty camera frame.
# Ignoring empty camera frame.
# Ignoring empty camera frame.
# Ignoring empty camera frame.
# Ignoring empty camera frame.
# Ignoring empty camera frame.
# Ignoring empty camera frame.
# Ignoring empty camera frame.
# ...

# %%
for file in data_test_new:
    path ='/data/wlasl_2000/'+file['video_file']   
    cap = cv2.VideoCapture(path)
    resize =256
    dest_path = '/data/wlasl_2000/wlasl_resized/'+file['video_file']

    frame_width, frame_height = int(cap.get(3)), int(cap.get(4))


    out = cv2.VideoWriter(dest_path, cv2.VideoWriter_fourcc(
        'm', 'p', '4', 'v'), 30, (resize, resize))



    while cap.isOpened():
        success, image = cap.read()
        if not success:
            print("Ignoring empty camera frame.")
            # If loading a video, use 'break' instead of 'continue'.
            break
        #ret, frame = cap.read()
        img = cv2.resize(image, (resize, resize))

        out.write(img)
    cap.release()
    out.release()
# Out:
# Ignoring empty camera frame.
# Ignoring empty camera frame.
# Ignoring empty camera frame.
# Ignoring empty camera frame.
# Ignoring empty camera frame.
# Ignoring empty camera frame.
# Ignoring empty camera frame.
# Ignoring empty camera frame.
# Ignoring empty camera frame.
# Ignoring empty camera frame.
# Ignoring empty camera frame.
# Ignoring empty camera frame.
# Ignoring empty camera frame.
# Ignoring empty camera frame.
# Ignoring empty camera frame.
# Ignoring empty camera frame.
# Ignoring empty camera frame.
# Ignoring empty camera frame.
# Ignoring empty camera frame.
# Ignoring empty camera frame.
# Ignoring empty camera frame.
# Ignoring empty camera frame.
# Ignoring empty camera frame.
# Ignoring empty camera frame.
# Ignoring empty camera frame.
# Ignoring empty camera frame.
# Ignoring empty camera frame.
# Ignoring empty camera frame.
# Ignoring empty camera frame.
# Ignoring empty camera frame.
# Ignoring empty camera frame.
# Ignoring empty camera frame.
# ...

# %%
for file in data_dev_new:
    path ='/data/wlasl_2000/'+file['video_file']   
    cap = cv2.VideoCapture(path)
    resize =256
    dest_path = '/data/wlasl_2000/wlasl_resized/'+file['video_file']

    frame_width, frame_height = int(cap.get(3)), int(cap.get(4))


    out = cv2.VideoWriter(dest_path, cv2.VideoWriter_fourcc(
        'm', 'p', '4', 'v'), 30, (resize, resize))

    while cap.isOpened():
        success, image = cap.read()
        if not success:
            print("Ignoring empty camera frame.")
            # If loading a video, use 'break' instead of 'continue'.
            break
        #ret, frame = cap.read()
        img = cv2.resize(image, (resize, resize))

        out.write(img)
    cap.release()
    out.release()
# Out:
# Ignoring empty camera frame.
# Ignoring empty camera frame.
# Ignoring empty camera frame.
# Ignoring empty camera frame.
# Ignoring empty camera frame.
# Ignoring empty camera frame.
# Ignoring empty camera frame.
# Ignoring empty camera frame.
# Ignoring empty camera frame.
# Ignoring empty camera frame.
# Ignoring empty camera frame.
# Ignoring empty camera frame.
# Ignoring empty camera frame.
# Ignoring empty camera frame.
# Ignoring empty camera frame.
# Ignoring empty camera frame.
# Ignoring empty camera frame.
# Ignoring empty camera frame.
# Ignoring empty camera frame.
# Ignoring empty camera frame.
# Ignoring empty camera frame.
# Ignoring empty camera frame.
# Ignoring empty camera frame.
# Ignoring empty camera frame.
# Ignoring empty camera frame.
# Ignoring empty camera frame.
# Ignoring empty camera frame.
# Ignoring empty camera frame.
# Ignoring empty camera frame.
# Ignoring empty camera frame.
# Ignoring empty camera frame.
# Ignoring empty camera frame.
# ...
